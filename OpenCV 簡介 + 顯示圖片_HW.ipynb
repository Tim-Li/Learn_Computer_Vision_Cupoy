# %% [markdown]
# # 作業
#
# 思考一下我們前面有提到圖片是矩陣，但維度可能會不一樣
# 例如灰階圖只有兩個維度，RGB 彩圖則有 3 個維度
#
# 假如今天我們把 RGB 3 個維度拆開來看會有甚麼不同的效果呢？

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"C:/Users/USER/Desktop/Learning_ai/python_for_microscopists/images/einstein_mona_lisa/monalisa_original.jpg", -1)

# split channel to (b,g,r)
b,g,r = cv2.split(img)

img = cv2.merge([r,g,b])

# %%
plt.figure(figsize=(14,10))
plt.subplot(221)
plt.imshow(img)
plt.title("This is origin image")
plt.subplot(222)
plt.imshow(b,cmap="gray")
plt.title("This is b channel image")
plt.subplot(223)
plt.imshow(g,cmap="gray")
plt.title("This is g channel image")
plt.subplot(224)
plt.imshow(r,cmap="gray")
plt.title("This is r channel image")
# Out:
# Text(0.5, 1.0, 'This is r channel image')
